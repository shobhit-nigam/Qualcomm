# %%
import pandas as pd #convention to use pd

# %%
dfa = pd.read_csv('SalesJan2009.csv')

# %%
dfa
# Out:
#     Transaction_date   Product Price Payment_Type               Name  \
# 0        1/2/09 6:17  Product1  1200   Mastercard           carolina
# 1        1/2/09 4:53  Product1  1200         Visa             Betina
# 2       1/2/09 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3       1/3/09 14:44  Product1  1200         Visa              Gouya
# 4       1/4/09 12:56  Product2  3600         Visa            Gerd W
# ..               ...       ...   ...          ...                ...
# 993    1/22/09 14:25  Product1  1200         Visa         Hans-Joerg
# 994     1/28/09 5:36  Product2  3600         Visa         Christiane
# 995      1/1/09 4:24  Product3  7500         Amex             Pamela
# 996     1/8/09 11:55  Product1  1200       Diners              julie
# 997    1/12/09 21:30  Product1  1200         Visa             Julia
#
#                              City             State         Country  \
# 0                        Basildon           England  United Kingdom
# ...

# %%
dfa.shape
# Out:
# (998, 12)

# %%
dfa.shape[1]
# Out:
# 12

# %%
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  998 non-null    object
#  1   Product           998 non-null    object
#  2   Price             998 non-null    object
#  3   Payment_Type      998 non-null    object
#  4   Name              998 non-null    object
#  5   City              998 non-null    object
#  6   State             997 non-null    object
#  7   Country           998 non-null    object
#  8   Account_Created   998 non-null    object
#  9   Last_Login        998 non-null    object
#  10  Latitude          998 non-null    float64
#  11  Longitude         998 non-null    float64
# dtypes: float64(2), object(10)
# memory usage: 93.7+ KB

# %%
dfa.columns
# Out:
# Index(['Transaction_date', 'Product', 'Price', 'Payment_Type', 'Name', 'City',
#        'State', 'Country', 'Account_Created', 'Last_Login', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
col = list(dfa.columns)

# %%
col
# Out:
# ['Transaction_date',
#  'Product',
#  'Price',
#  'Payment_Type',
#  'Name',
#  'City',
#  'State',
#  'Country',
#  'Account_Created',
#  'Last_Login',
#  'Latitude',
#  'Longitude']

# %%
dfa.head(7)
# Out:
#   Transaction_date   Product Price Payment_Type               Name  \
# 0      1/2/09 6:17  Product1  1200   Mastercard           carolina
# 1      1/2/09 4:53  Product1  1200         Visa             Betina
# 2     1/2/09 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3     1/3/09 14:44  Product1  1200         Visa              Gouya
# 4     1/4/09 12:56  Product2  3600         Visa            Gerd W
# 5     1/4/09 13:19  Product1  1200         Visa           LAURENCE
# 6     1/4/09 20:11  Product1  1200   Mastercard              Fleur
#
#                            City     State         Country Account_Created  \
# 0                      Basildon   England  United Kingdom     1/2/09 6:00
# 1  Parkville                           MO   United States     1/2/09 4:42
# 2  Astoria                             OR   United States    1/1/09 16:21
# 3                        Echuca  Victoria       Australia   9/25/05 21:13
# ...

# %%
dfa[600:610]
# Out:
#     Transaction_date   Product Price Payment_Type         Name  \
# 600    1/14/09 13:23  Product1  1200       Diners      eugenia
# 601     1/7/09 20:01  Product1  1200         Visa        Karen
# 602    1/20/09 12:32  Product1  1200         Visa          Bea
# 603     1/6/09 14:35  Product1  1200       Diners  Hilde Karin
# 604      1/4/09 6:51  Product1  1200         Visa         Rima
# 605    1/24/09 18:30  Product1  1200         Visa    Ruangrote
# 606     1/25/09 5:57  Product1  1200         Amex       pamela
# 607     1/5/09 10:02  Product2  3600         Visa      Emillie
# 608     1/13/09 9:14  Product1  1200         Visa     sangeeta
# 609     1/22/09 7:35  Product1  1200         Visa         Anja
#
#                              City         State        Country  \
# 600  Wisconsin Rapids                        WI  United States
# 601  Austin                                  TX  United States
# 602  Chicago                                 IL  United States
# ...

# %%
dfa[['Name', 'City', 'Price']]
# Out:
#                   Name                          City Price
# 0             carolina                      Basildon  1200
# 1               Betina  Parkville                     1200
# 2    Federica e Andrea  Astoria                       1200
# 3                Gouya                        Echuca  1200
# 4              Gerd W   Cahaba Heights                3600
# ..                 ...                           ...   ...
# 993         Hans-Joerg                       Belfast  1200
# 994         Christiane                   Black River  3600
# 995             Pamela  Skaneateles                   7500
# 996              julie                     Haverhill  1200
# 997             Julia   Madison                       1200
#
# [998 rows x 3 columns]

# %%
dfa
# Out:
#     Transaction_date   Product Price Payment_Type               Name  \
# 0        1/2/09 6:17  Product1  1200   Mastercard           carolina
# 1        1/2/09 4:53  Product1  1200         Visa             Betina
# 2       1/2/09 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3       1/3/09 14:44  Product1  1200         Visa              Gouya
# 4       1/4/09 12:56  Product2  3600         Visa            Gerd W
# ..               ...       ...   ...          ...                ...
# 993    1/22/09 14:25  Product1  1200         Visa         Hans-Joerg
# 994     1/28/09 5:36  Product2  3600         Visa         Christiane
# 995      1/1/09 4:24  Product3  7500         Amex             Pamela
# 996     1/8/09 11:55  Product1  1200       Diners              julie
# 997    1/12/09 21:30  Product1  1200         Visa             Julia
#
#                              City             State         Country  \
# 0                        Basildon           England  United Kingdom
# ...

# %%
dfa['Product']
dfa.Product
# Out:
# 0      Product1
# 1      Product1
# 2      Product1
# 3      Product1
# 4      Product2
#          ...
# 993    Product1
# 994    Product2
# 995    Product3
# 996    Product1
# 997    Product1
# Name: Product, Length: 998, dtype: object

# %%
dfa.Product.unique()
# Out:
# array(['Product1', 'Product2', 'Product3', 'Product3 '], dtype=object)

# %%
dfb = pd.read_excel('one.xlsx', sheet_name='wednesday', header=None)

# %%
dfb
# Out:
#     0   1   2
# 0  12  34  77
# 1  88  14  98
# 2  87  65  43
# 3  23  76  34
# 4  45  12  77
# 5  94  72  56
# 6  89  28  47
# 7  33  56  92

# %%
dfb = pd.ExcelFile('one.xlsx')

# %%
dfb.sheet_names
# Out:
# ['tuesday', 'wednesday']

# %%
dfb

# %%
dfb = pd.read_excel('one.xlsx', sheet_name='wednesday', header=None)

# %%
dfb[1].sum()
# Out:
# 357

# %%
dfb[1].mean()
# Out:
# 44.625

# %%
dfb.describe()
# Out:
#                0          1          2
# count   8.000000   8.000000   8.000000
# mean   58.875000  44.625000  65.500000
# std    34.073188  25.828763  23.766723
# min    12.000000  12.000000  34.000000
# 25%    30.500000  24.500000  46.000000
# 50%    66.000000  45.000000  66.500000
# 75%    88.250000  66.750000  80.750000
# max    94.000000  76.000000  98.000000

# %%
dfa.describe()
# Out:
#          Latitude   Longitude
# count  998.000000  998.000000
# mean    39.015705  -41.337820
# std     19.508572   67.389479
# min    -41.465000 -159.485280
# 25%     35.816944  -87.991670
# 50%     42.320695  -73.730695
# 75%     51.050000    4.916667
# max     64.837780  174.766667

# %%
dfa.isna().sum()
# Out:
# Transaction_date    0
# Product             0
# Price               0
# Payment_Type        0
# Name                0
# City                0
# State               1
# Country             0
# Account_Created     0
# Last_Login          0
# Latitude            0
# Longitude           0
# dtype: int64

# %%
#  NaN

# %%
dfc = pd.read_csv('effects-of-covid-19-on-trade-1-february-20-may-2020-provisional-csv.csv')

# %%
dfc.shape
# Out:
# (24880, 11)

# %%
dfc.columns
# Out:
# Index(['Direction', 'Year', 'Date', 'Weekday', 'Current_Match', 'Country',
#        'Commodity', 'Transport_Mode', 'Measure', 'Value', 'Cumulative'],
#       dtype='object')

# %%
dfc
# Out:
#        Direction  Year        Date    Weekday Current_Match Country Commodity  \
# 0        Exports  2015  31/01/2015   Saturday    01/02/2020     All       All
# 1        Exports  2015  01/02/2015     Sunday    02/02/2020     All       All
# 2        Exports  2015  02/02/2015     Monday    03/02/2020     All       All
# 3        Exports  2015  03/02/2015    Tuesday    04/02/2020     All       All
# 4        Exports  2015  04/02/2015  Wednesday    05/02/2020     All       All
# ...          ...   ...         ...        ...           ...     ...       ...
# 24875  Reimports  2020  26/04/2020     Sunday    26/04/2020     All       All
# 24876  Reimports  2020  27/04/2020     Monday    27/04/2020     All       All
# 24877  Reimports  2020  28/04/2020    Tuesday    28/04/2020     All       All
# 24878  Reimports  2020  29/04/2020  Wednesday    29/04/2020     All       All
# 24879  Reimports  2020  30/04/2020   Thursday    30/04/2020     All       All
#
# ...

# %%
dfc.Year.unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019, 2020])

# %%
dfc.Year.value_counts()
# Out:
# 2015    4158
# 2019    4152
# 2016    4149
# 2018    4147
# 2017    4147
# 2020    4127
# Name: Year, dtype: int64

# %%
dfc.Direction.unique()
# Out:
# array(['Exports', 'Imports', 'Reimports'], dtype=object)

# %%
dfb
# Out:
#     0   1   2
# 0  12  34  77
# 1  88  14  98
# 2  87  65  43
# 3  23  76  34
# 4  45  12  77
# 5  94  72  56
# 6  89  28  47
# 7  33  56  92

# %%
dfb.sort_values([1])
# Out:
#     0   1   2
# 4  45  12  77
# 1  88  14  98
# 6  89  28  47
# 0  12  34  77
# 7  33  56  92
# 2  87  65  43
# 5  94  72  56
# 3  23  76  34

# %%
dfb_sort = dfb.sort_values([1], ascending=False)

# %%
dfb
# Out:
#     0   1   2
# 0  12  34  77
# 1  88  14  98
# 2  87  65  43
# 3  23  76  34
# 4  45  12  77
# 5  94  72  56
# 6  89  28  47
# 7  33  56  92

# %%
dfb_sort
# Out:
#     0   1   2
# 3  23  76  34
# 5  94  72  56
# 2  87  65  43
# 7  33  56  92
# 0  12  34  77
# 6  89  28  47
# 1  88  14  98
# 4  45  12  77

# %%
dfc[dfc['Value'] > 310000000]
# Out:
#       Direction  Year        Date    Weekday Current_Match  \
# 29      Exports  2015  01/03/2015     Sunday    01/03/2020
# 131     Exports  2016  20/02/2016   Saturday    22/02/2020
# 381     Exports  2018  26/03/2018     Monday    23/03/2020
# 437     Exports  2018  21/05/2018     Monday    18/05/2020
# 457     Exports  2019  19/02/2019    Tuesday    18/02/2020
# 596     Exports  2020  18/03/2020  Wednesday    18/03/2020
# 597     Exports  2020  19/03/2020   Thursday    19/03/2020
# 603     Exports  2020  25/03/2020  Wednesday    25/03/2020
# 4649    Exports  2015  01/03/2015     Sunday    01/03/2020
# 4751    Exports  2016  20/02/2016   Saturday    22/02/2020
# 5077    Exports  2019  19/02/2019    Tuesday    18/02/2020
# 5969    Exports  2015  01/03/2015     Sunday    01/03/2020
# 6071    Exports  2016  20/02/2016   Saturday    22/02/2020
# 6321    Exports  2018  26/03/2018     Monday    23/03/2020
# 6377    Exports  2018  21/05/2018     Monday    18/05/2020
# ...

# %%
dfb
# Out:
#     0   1   2
# 0  12  34  77
# 1  88  14  98
# 2  87  65  43
# 3  23  76  34
# 4  45  12  77
# 5  94  72  56
# 6  89  28  47
# 7  33  56  92

# %%
dfb.rename(columns={0:'one', 1:'two', 2:'three'}, inplace=True)

# %%
dfb
# Out:
#    one  two  three
# 0   12   34     77
# 1   88   14     98
# 2   87   65     43
# 3   23   76     34
# 4   45   12     77
# 5   94   72     56
# 6   89   28     47
# 7   33   56     92

# %%
dfb.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
dfc[(dfc['Value'] > 310000000) & (dfc['Transport_Mode'] == 'Sea')]
# Out:
#       Direction  Year        Date    Weekday Current_Match Country Commodity  \
# 5969    Exports  2015  01/03/2015     Sunday    01/03/2020     All       All
# 6071    Exports  2016  20/02/2016   Saturday    22/02/2020     All       All
# 6321    Exports  2018  26/03/2018     Monday    23/03/2020     All       All
# 6377    Exports  2018  21/05/2018     Monday    18/05/2020     All       All
# 6397    Exports  2019  19/02/2019    Tuesday    18/02/2020     All       All
# 6543    Exports  2020  25/03/2020  Wednesday    25/03/2020     All       All
# 23576   Imports  2019  22/05/2019  Wednesday    20/05/2020     All       All
# 23631   Imports  2020  26/03/2020   Thursday    26/03/2020     All       All
#
#       Transport_Mode Measure      Value   Cumulative
# 5969             Sea       $  373000000   4032000000
# 6071             Sea       $  353000000   2990000000
# 6321             Sea       $  312000000   7336000000
# 6377             Sea       $  322000000  15888000000
# ...

# %%
dfc
# Out:
#        Direction  Year        Date    Weekday Current_Match Country Commodity  \
# 0        Exports  2015  31/01/2015   Saturday    01/02/2020     All       All
# 1        Exports  2015  01/02/2015     Sunday    02/02/2020     All       All
# 2        Exports  2015  02/02/2015     Monday    03/02/2020     All       All
# 3        Exports  2015  03/02/2015    Tuesday    04/02/2020     All       All
# 4        Exports  2015  04/02/2015  Wednesday    05/02/2020     All       All
# ...          ...   ...         ...        ...           ...     ...       ...
# 24875  Reimports  2020  26/04/2020     Sunday    26/04/2020     All       All
# 24876  Reimports  2020  27/04/2020     Monday    27/04/2020     All       All
# 24877  Reimports  2020  28/04/2020    Tuesday    28/04/2020     All       All
# 24878  Reimports  2020  29/04/2020  Wednesday    29/04/2020     All       All
# 24879  Reimports  2020  30/04/2020   Thursday    30/04/2020     All       All
#
# ...

# %%
dfc[(dfc['Value'] > 310000000) & (dfc['Cumulative'] > 310000000)]
# Out:
#       Direction  Year        Date    Weekday Current_Match  \
# 29      Exports  2015  01/03/2015     Sunday    01/03/2020
# 131     Exports  2016  20/02/2016   Saturday    22/02/2020
# 381     Exports  2018  26/03/2018     Monday    23/03/2020
# 437     Exports  2018  21/05/2018     Monday    18/05/2020
# 457     Exports  2019  19/02/2019    Tuesday    18/02/2020
# 596     Exports  2020  18/03/2020  Wednesday    18/03/2020
# 597     Exports  2020  19/03/2020   Thursday    19/03/2020
# 603     Exports  2020  25/03/2020  Wednesday    25/03/2020
# 4649    Exports  2015  01/03/2015     Sunday    01/03/2020
# 4751    Exports  2016  20/02/2016   Saturday    22/02/2020
# 5077    Exports  2019  19/02/2019    Tuesday    18/02/2020
# 5969    Exports  2015  01/03/2015     Sunday    01/03/2020
# 6071    Exports  2016  20/02/2016   Saturday    22/02/2020
# 6321    Exports  2018  26/03/2018     Monday    23/03/2020
# 6377    Exports  2018  21/05/2018     Monday    18/05/2020
# ...

# %%
dfc[4:10]
# Out:
#   Direction  Year        Date    Weekday Current_Match Country Commodity  \
# 4   Exports  2015  04/02/2015  Wednesday    05/02/2020     All       All
# 5   Exports  2015  05/02/2015   Thursday    06/02/2020     All       All
# 6   Exports  2015  06/02/2015     Friday    07/02/2020     All       All
# 7   Exports  2015  07/02/2015   Saturday    08/02/2020     All       All
# 8   Exports  2015  08/02/2015     Sunday    09/02/2020     All       All
# 9   Exports  2015  09/02/2015     Monday    10/02/2020     All       All
#
#   Transport_Mode Measure      Value  Cumulative
# 4            All       $   74000000   746000000
# 5            All       $  119000000   864000000
# 6            All       $  127000000   992000000
# 7            All       $  206000000  1198000000
# 8            All       $  114000000  1312000000
# 9            All       $  202000000  1513000000

# %%
dfc.loc[4, 'Year']
# Out:
# 2015

# %%
len(dfb)
# Out:
# 8

# %%
listx = ['aa', 'bb', 'cc', 'dd', 'ee', 'ff', 'gg', 'hh']

# %%
dfb
# Out:
#    one  two  three
# 0   12   34     77
# 1   88   14     98
# 2   87   65     43
# 3   23   76     34
# 4   45   12     77
# 5   94   72     56
# 6   89   28     47
# 7   33   56     92

# %%
dfb['four'] = listx

# %%
dfb
# Out:
#    one  two  three four
# 0   12   34     77   aa
# 1   88   14     98   bb
# 2   87   65     43   cc
# 3   23   76     34   dd
# 4   45   12     77   ee
# 5   94   72     56   ff
# 6   89   28     47   gg
# 7   33   56     92   hh

# %%
dfb.to_excel('four.xlsx', index=False)

# %%
dfc.head(3)
# Out:
#   Direction  Year        Date   Weekday Current_Match Country Commodity  \
# 0   Exports  2015  31/01/2015  Saturday    01/02/2020     All       All
# 1   Exports  2015  01/02/2015    Sunday    02/02/2020     All       All
# 2   Exports  2015  02/02/2015    Monday    03/02/2020     All       All
#
#   Transport_Mode Measure      Value  Cumulative
# 0            All       $  257000000   257000000
# 1            All       $  123000000   380000000
# 2            All       $  176000000   556000000

# %%
dfc.Weekday.unique()
# Out:
# array(['Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday',
#        'Friday'], dtype=object)

# %%
dfc.Weekday.value_counts()
# Out:
# Sunday       3619
# Monday       3619
# Tuesday      3617
# Saturday     3616
# Wednesday    3615
# Friday       3401
# Thursday     3393
# Name: Weekday, dtype: int64

# %%
listp = ['Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday','Friday']

# %%
listq = [8, 1, 2, 3, 7, 8, 6]

# %%
listr = ['aa', 'bb', 'cc', 'ee', 'ff', 'gg', 'hh']

# %%
z = zip(listp, listq, listr)

# %%
dict((z[0]), list(z[1:])) for z in zip(listp, listq, listr)
# Out:
#   File "<ipython-input-98-7e35b7487aa8>", line 1
#     dict((z[0]), list(z[1:])) for z in zip(listp, listq, listr)
#                                 ^
# SyntaxError: invalid syntax

# %%
d = dict(zip(listp, zip(listq, listr)))

# %%
d
# Out:
# {'Saturday': (8, 'aa'),
#  'Sunday': (1, 'bb'),
#  'Monday': (2, 'cc'),
#  'Tuesday': (3, 'ee'),
#  'Wednesday': (7, 'ff'),
#  'Thursday': (8, 'gg'),
#  'Friday': (6, 'hh')}

# %%
dfd = pd.DataFrame(d)

# %%
dfd
# Out:
#   Saturday Sunday Monday Tuesday Wednesday Thursday Friday
# 0        8      1      2       3         7        8      6
# 1       aa     bb     cc      ee        ff       gg     hh

# %%
za = zip(listp, listq)

# %%
tuple(za)
# Out:
# (('Saturday', 8),
#  ('Sunday', 1),
#  ('Monday', 2),
#  ('Tuesday', 3),
#  ('Wednesday', 7),
#  ('Thursday', 8),
#  ('Friday', 6))

# %%
dict(za)
# Out:
# {'Saturday': 8,
#  'Sunday': 1,
#  'Monday': 2,
#  'Tuesday': 3,
#  'Wednesday': 7,
#  'Thursday': 8,
#  'Friday': 6}
